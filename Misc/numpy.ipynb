# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
theta = np.linspace(0, 2*np.pi, 100)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
y.shape
# Out:
# (100,)

# %%
r = 3
x = r*np.cos(theta)
y = r*np.sin(theta)

# %%
plt.figure(figsize = (4,4))
plt.plot(x,y)

# %%
x = np.linspace(2,20, 1000)
m , c = 3, 10
y = m*x + c
plt.scatter(x,y)

# %%
noise = np.random.randn(1000)
y_mod = y + noise
plt.scatter(x, y_mod)

# %%
x = np.random.randn(1000)
out = plt.hist(x,bins = 100)

# %%
out = plt.pie([10,20,30],explode = [0, .1, 0], shadow = True, radius = 0.5)

# %%
import seaborn as sns

# %%
x = np.random.randn(10000)

# %%
sns.distplot(x, bins = 100, kde = False, rug = True)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:>

# %%
data = sns.load_dataset("tips")

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data["total_bill"], data["tip"], hue = data["time"])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.violinplot(x = data.total_bill, hue = data.smoker)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
from sklearn.datasets import load_boston

# %%
X,y = load_boston(return_X_y=True)

# %%
sns.violinplot(x=y)
# Out:
# <AxesSubplot:>

# %%
a = np.array([2]*5, dtype = "int32")

# %%
a
# Out:
# array([2, 2, 2, 2, 2])
