# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
bruh = Image.open("bruh.jpg")
img = np.array(bruh)

# %%
img.shape
# Out:
# (667, 734, 3)

# %%
gray = img.mean(axis = 2)

# %%
plt.imshow(gray, cmap = "gray")

# %%
class student:
    def __init__(self,name,rollno,m1,m2):
        self.name=name
        self.rollno=rollno
        self.m1=m1
        self.m2=m2
    def display(self):
        print(f'''name is {self.name}
rollno is {self.rollno}
marks in subj1 is {self.m1}
marks in subj2 is {self.m2}''')
    def search(rollno):
        if rollno==12:
            s2.display()
        elif rollno==10:
            s1.display()
    def delete(self, rollno):
        if rollno==12:
            del self
        elif rollno==10:
            del self


s1=student('abbas',10,73,89)
s2=student('harry',12,76,63)

#student.search(10)
del s1
s1.display()
s2.display()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-59d1b4b2d515> in <module>
#      27 #student.search(10)
#      28 del s1
# ---> 29 s1.display()
#      30 s2.display()
#
# NameError: name 's1' is not defined
